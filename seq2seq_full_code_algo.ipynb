# %% [markdown]
# # Use Case:  Language Translator
# dataset consisting of pairs of English sentences and their French translation,

# %%
from __future__ import print_function

from keras.models import Model
from keras.layers import Input, LSTM, Dense
import numpy as np
# Out:
# 2023-08-01 20:04:17.409435: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = 'fra-eng (1)/fra.txt'

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')

# %%
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text, _ = line.split('\t')
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

# %%
input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

# %%
print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of samples: 10000
# Number of unique input tokens: 70
# Number of unique output tokens: 93
# Max sequence length for inputs: 14
# Max sequence length for outputs: 59

# %%
input_token_index = dict(
    [(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict(
    [(char, i) for i, char in enumerate(target_characters)])

# %%
"""Turn the sentences into 3 Numpy arrays, encoder_input_data, decoder_input_data, decoder_target_data:

encoder_input_data is a 3D array of shape (num_pairs, max_english_sentence_length, num_english_characters) containing a one-hot vectorization of the English sentences
decoder_input_data is a 3D array of shape (num_pairs, max_french_sentence_length, num_french_characters) containing a one-hot vectorization of the French sentences
decoder_target_data is the same as decoder_input_data but offset by one timestep. decoder_target_data[:, t, :] will be the same as decoder_input_data[:, t + 1, :]
"""

encoder_input_data = np.zeros((len(input_texts), max_encoder_seq_length, num_encoder_tokens),dtype='float32')
decoder_input_data = np.zeros((len(input_texts), max_decoder_seq_length, num_decoder_tokens),dtype='float32')
decoder_target_data = np.zeros((len(input_texts), max_decoder_seq_length, num_decoder_tokens),dtype='float32')

# %%
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    encoder_input_data[i, t + 1:, input_token_index[' ']] = 1.
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.
    decoder_input_data[i, t + 1:, target_token_index[' ']] = 1.
    decoder_target_data[i, t:, target_token_index[' ']] = 1.

# %%
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]
# Out:
# 2023-08-01 20:04:18.934083: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-01 20:04:18.963418: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-01 20:04:18.963547: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-01 20:04:18.964115: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-01 20:04:18.965150: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-01 20:04:18.965253: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-01 20:04:18.965323: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-01 20:04:19.001513: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-01 20:04:19.001635: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-01 20:04:19.001720: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-01 20:04:19.001798: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1892 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
#Train a basic LSTM-based Seq2Seq model to predict decoder_target_data given encoder_input_data and decoder_input_data

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
# Run training
model.compile(optimizer='rmsprop', loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)
# Save model
model.save('s2s.h5')
# Out:
# Epoch 1/100
#   6/125 [>.............................] - ETA: 1s - loss: 2.5822 - accuracy: 0.6098
# 2023-08-01 20:04:20.877852: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8600
# 2023-08-01 20:04:20.910428: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 125/125 [==============================] - 3s 13ms/step - loss: 1.1346 - accuracy: 0.7377 - val_loss: 0.9865 - val_accuracy: 0.7326
# Epoch 2/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.8047 - accuracy: 0.7822 - val_loss: 0.8606 - val_accuracy: 0.7743
# Epoch 3/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.6438 - accuracy: 0.8186 - val_loss: 0.6644 - val_accuracy: 0.8099
# Epoch 4/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.5609 - accuracy: 0.8372 - val_loss: 0.6045 - val_accuracy: 0.8249
# Epoch 5/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.5131 - accuracy: 0.8504 - val_loss: 0.5824 - val_accuracy: 0.8294
# Epoch 6/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.4800 - accuracy: 0.8595 - val_loss: 0.5386 - val_accuracy: 0.8421
# Epoch 7/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.4536 - accuracy: 0.8658 - val_loss: 0.5214 - val_accuracy: 0.8457
# Epoch 8/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.4312 - accuracy: 0.8719 - val_loss: 0.5020 - val_accuracy: 0.8522
# Epoch 9/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.4121 - accuracy: 0.8770 - val_loss: 0.4879 - val_accuracy: 0.8561
# Epoch 10/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.3943 - accuracy: 0.8820 - val_loss: 0.4788 - val_accuracy: 0.8592
# Epoch 11/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.3779 - accuracy: 0.8866 - val_loss: 0.4676 - val_accuracy: 0.8614
# Epoch 12/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3625 - accuracy: 0.8915 - val_loss: 0.4605 - val_accuracy: 0.8642
# Epoch 13/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3488 - accuracy: 0.8950 - val_loss: 0.4522 - val_accuracy: 0.8659
# Epoch 14/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.3346 - accuracy: 0.8997 - val_loss: 0.4446 - val_accuracy: 0.8695
# Epoch 15/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3224 - accuracy: 0.9030 - val_loss: 0.4397 - val_accuracy: 0.8702
# Epoch 16/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3105 - accuracy: 0.9065 - val_loss: 0.4374 - val_accuracy: 0.8712
# Epoch 17/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2993 - accuracy: 0.9097 - val_loss: 0.4325 - val_accuracy: 0.8738
# Epoch 18/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2884 - accuracy: 0.9128 - val_loss: 0.4310 - val_accuracy: 0.8736
# Epoch 19/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2779 - accuracy: 0.9162 - val_loss: 0.4267 - val_accuracy: 0.8763
# Epoch 20/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2682 - accuracy: 0.9188 - val_loss: 0.4283 - val_accuracy: 0.8759
# Epoch 21/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2585 - accuracy: 0.9217 - val_loss: 0.4259 - val_accuracy: 0.8781
# Epoch 22/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2498 - accuracy: 0.9244 - val_loss: 0.4263 - val_accuracy: 0.8773
# Epoch 23/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2407 - accuracy: 0.9269 - val_loss: 0.4267 - val_accuracy: 0.8790
# Epoch 24/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2326 - accuracy: 0.9297 - val_loss: 0.4282 - val_accuracy: 0.8797
# Epoch 25/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2246 - accuracy: 0.9317 - val_loss: 0.4291 - val_accuracy: 0.8789
# Epoch 26/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2169 - accuracy: 0.9343 - val_loss: 0.4314 - val_accuracy: 0.8788
# Epoch 27/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2098 - accuracy: 0.9363 - val_loss: 0.4289 - val_accuracy: 0.8812
# Epoch 28/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2029 - accuracy: 0.9385 - val_loss: 0.4326 - val_accuracy: 0.8801
# Epoch 29/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1962 - accuracy: 0.9405 - val_loss: 0.4364 - val_accuracy: 0.8801
# Epoch 30/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1895 - accuracy: 0.9427 - val_loss: 0.4385 - val_accuracy: 0.8802
# Epoch 31/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1837 - accuracy: 0.9441 - val_loss: 0.4432 - val_accuracy: 0.8802
# Epoch 32/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1776 - accuracy: 0.9461 - val_loss: 0.4465 - val_accuracy: 0.8810
# Epoch 33/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1721 - accuracy: 0.9476 - val_loss: 0.4458 - val_accuracy: 0.8816
# Epoch 34/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1666 - accuracy: 0.9493 - val_loss: 0.4521 - val_accuracy: 0.8808
# Epoch 35/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1615 - accuracy: 0.9506 - val_loss: 0.4534 - val_accuracy: 0.8815
# Epoch 36/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1565 - accuracy: 0.9520 - val_loss: 0.4579 - val_accuracy: 0.8811
# Epoch 37/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1519 - accuracy: 0.9534 - val_loss: 0.4665 - val_accuracy: 0.8807
# Epoch 38/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1474 - accuracy: 0.9548 - val_loss: 0.4656 - val_accuracy: 0.8808
# Epoch 39/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1427 - accuracy: 0.9564 - val_loss: 0.4692 - val_accuracy: 0.8814
# Epoch 40/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1387 - accuracy: 0.9575 - val_loss: 0.4759 - val_accuracy: 0.8816
# Epoch 41/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1347 - accuracy: 0.9587 - val_loss: 0.4774 - val_accuracy: 0.8805
# Epoch 42/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1312 - accuracy: 0.9596 - val_loss: 0.4840 - val_accuracy: 0.8805
# Epoch 43/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1271 - accuracy: 0.9610 - val_loss: 0.4920 - val_accuracy: 0.8799
# Epoch 44/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1242 - accuracy: 0.9617 - val_loss: 0.4923 - val_accuracy: 0.8806
# Epoch 45/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1203 - accuracy: 0.9628 - val_loss: 0.5020 - val_accuracy: 0.8797
# Epoch 46/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1169 - accuracy: 0.9637 - val_loss: 0.5010 - val_accuracy: 0.8815
# Epoch 47/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1141 - accuracy: 0.9647 - val_loss: 0.5089 - val_accuracy: 0.8803
# Epoch 48/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1108 - accuracy: 0.9658 - val_loss: 0.5124 - val_accuracy: 0.8806
# Epoch 49/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1077 - accuracy: 0.9665 - val_loss: 0.5155 - val_accuracy: 0.8810
# Epoch 50/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1053 - accuracy: 0.9672 - val_loss: 0.5162 - val_accuracy: 0.8815
# Epoch 51/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1027 - accuracy: 0.9680 - val_loss: 0.5196 - val_accuracy: 0.8813
# Epoch 52/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1000 - accuracy: 0.9686 - val_loss: 0.5287 - val_accuracy: 0.8801
# Epoch 53/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0979 - accuracy: 0.9693 - val_loss: 0.5331 - val_accuracy: 0.8802
# Epoch 54/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0951 - accuracy: 0.9702 - val_loss: 0.5362 - val_accuracy: 0.8813
# Epoch 55/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0929 - accuracy: 0.9709 - val_loss: 0.5384 - val_accuracy: 0.8809
# Epoch 56/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0905 - accuracy: 0.9712 - val_loss: 0.5436 - val_accuracy: 0.8801
# Epoch 57/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0884 - accuracy: 0.9720 - val_loss: 0.5539 - val_accuracy: 0.8801
# Epoch 58/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0865 - accuracy: 0.9725 - val_loss: 0.5524 - val_accuracy: 0.8797
# Epoch 59/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0846 - accuracy: 0.9731 - val_loss: 0.5597 - val_accuracy: 0.8803
# Epoch 60/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0824 - accuracy: 0.9738 - val_loss: 0.5645 - val_accuracy: 0.8803
# Epoch 61/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0808 - accuracy: 0.9742 - val_loss: 0.5722 - val_accuracy: 0.8798
# Epoch 62/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0788 - accuracy: 0.9747 - val_loss: 0.5730 - val_accuracy: 0.8798
# Epoch 63/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0769 - accuracy: 0.9754 - val_loss: 0.5764 - val_accuracy: 0.8789
# Epoch 64/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0756 - accuracy: 0.9755 - val_loss: 0.5859 - val_accuracy: 0.8791
# Epoch 65/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0739 - accuracy: 0.9762 - val_loss: 0.5836 - val_accuracy: 0.8800
# Epoch 66/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0722 - accuracy: 0.9765 - val_loss: 0.5893 - val_accuracy: 0.8800
# Epoch 67/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0709 - accuracy: 0.9770 - val_loss: 0.5980 - val_accuracy: 0.8800
# Epoch 68/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0692 - accuracy: 0.9773 - val_loss: 0.5994 - val_accuracy: 0.8795
# Epoch 69/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0682 - accuracy: 0.9777 - val_loss: 0.6042 - val_accuracy: 0.8795
# Epoch 70/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0665 - accuracy: 0.9779 - val_loss: 0.6104 - val_accuracy: 0.8796
# Epoch 71/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0653 - accuracy: 0.9787 - val_loss: 0.6080 - val_accuracy: 0.8794
# Epoch 72/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0640 - accuracy: 0.9790 - val_loss: 0.6150 - val_accuracy: 0.8788
# Epoch 73/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0629 - accuracy: 0.9792 - val_loss: 0.6176 - val_accuracy: 0.8792
# Epoch 74/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0619 - accuracy: 0.9795 - val_loss: 0.6268 - val_accuracy: 0.8783
# Epoch 75/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0605 - accuracy: 0.9799 - val_loss: 0.6268 - val_accuracy: 0.8790
# Epoch 76/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0593 - accuracy: 0.9802 - val_loss: 0.6300 - val_accuracy: 0.8796
# Epoch 77/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0583 - accuracy: 0.9804 - val_loss: 0.6365 - val_accuracy: 0.8794
# Epoch 78/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0583 - accuracy: 0.9803 - val_loss: 0.6369 - val_accuracy: 0.8797
# Epoch 79/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0565 - accuracy: 0.9810 - val_loss: 0.6363 - val_accuracy: 0.8795
# Epoch 80/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0559 - accuracy: 0.9811 - val_loss: 0.6497 - val_accuracy: 0.8789
# Epoch 81/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0544 - accuracy: 0.9817 - val_loss: 0.6496 - val_accuracy: 0.8790
# Epoch 82/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0536 - accuracy: 0.9817 - val_loss: 0.6501 - val_accuracy: 0.8787
# Epoch 83/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0530 - accuracy: 0.9820 - val_loss: 0.6524 - val_accuracy: 0.8787
# Epoch 84/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0519 - accuracy: 0.9822 - val_loss: 0.6642 - val_accuracy: 0.8782
# Epoch 85/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0512 - accuracy: 0.9824 - val_loss: 0.6712 - val_accuracy: 0.8783
# Epoch 86/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0507 - accuracy: 0.9825 - val_loss: 0.6660 - val_accuracy: 0.8790
# Epoch 87/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0497 - accuracy: 0.9830 - val_loss: 0.6735 - val_accuracy: 0.8780
# Epoch 88/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0488 - accuracy: 0.9833 - val_loss: 0.6792 - val_accuracy: 0.8779
# Epoch 89/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0484 - accuracy: 0.9832 - val_loss: 0.6789 - val_accuracy: 0.8779
# Epoch 90/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0476 - accuracy: 0.9836 - val_loss: 0.6783 - val_accuracy: 0.8791
# Epoch 91/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0471 - accuracy: 0.9835 - val_loss: 0.6873 - val_accuracy: 0.8784
# Epoch 92/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0465 - accuracy: 0.9836 - val_loss: 0.6863 - val_accuracy: 0.8788
# Epoch 93/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0460 - accuracy: 0.9835 - val_loss: 0.6973 - val_accuracy: 0.8780
# Epoch 94/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0452 - accuracy: 0.9840 - val_loss: 0.6947 - val_accuracy: 0.8777
# Epoch 95/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0447 - accuracy: 0.9842 - val_loss: 0.6932 - val_accuracy: 0.8783
# Epoch 96/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0444 - accuracy: 0.9843 - val_loss: 0.6977 - val_accuracy: 0.8780
# Epoch 97/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0434 - accuracy: 0.9843 - val_loss: 0.6994 - val_accuracy: 0.8778
# Epoch 98/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0435 - accuracy: 0.9843 - val_loss: 0.7045 - val_accuracy: 0.8786
# Epoch 99/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0429 - accuracy: 0.9845 - val_loss: 0.7060 - val_accuracy: 0.8788
# Epoch 100/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0427 - accuracy: 0.9847 - val_loss: 0.7099 - val_accuracy: 0.8778

# %%
# Next: inference mode (sampling).
# Here's the drill:
# 1) encode input and retrieve initial decoder state
# 2) run one step of decoder with this initial state
# and a "start of sequence" token as target.
# Output will be the next target token
# 3) Repeat with the current target token and current states

# Define sampling models
encoder_model = Model(encoder_inputs, encoder_states)

# %%
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# %%
# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index['\t']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
for seq_index in range(100):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('True:', target_text[seq_index])
    print('Decoded sentence:', decoded_sentence)
# Out:
# -
# True:
# Decoded sentence: En route !
#
# -
# True: Q
# Decoded sentence: En route !
#
# -
# True: u
# Decoded sentence: En route !
#
# -
# True: e
# Decoded sentence: En route !
#
# -
# True: l
# Decoded sentence: Salut.
#
# -
# True:
# Decoded sentence: Salut.
#
# -
# True: f
# Decoded sentence: Filez !
#
# -
# True: i
# Decoded sentence: Filez !
#
# -
# True: a
# Decoded sentence: Filez !
#
# -
# True: s
# Decoded sentence: Filez !
#
# -
# True: c
# Decoded sentence: Filez !
#
# -
# True: o
# Decoded sentence: Filez !
#
# -
# True:
# Decoded sentence: Filez !
#
# -
# True: !
# Decoded sentence: Filez !
#
# -
# True:
#
# Decoded sentence: Filez !
#
# -
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 7
#       5 decoded_sentence = decode_sequence(input_seq)
#       6 print('-')
# ----> 7 print('True:', target_text[seq_index])
#       8 print('Decoded sentence:', decoded_sentence)
#
# IndexError: string index out of range
